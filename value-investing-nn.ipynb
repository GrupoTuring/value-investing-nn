# %% [markdown]
# # Dependencies

# %%
# pandas
import pandas as pd

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score, cross_validate

# tf keras
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.losses import Huber

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('/content/drive/My Drive/Grupo Turing/value2.csv')

# %%
#df.head()
df.shape
# Out:
# (1330, 12)

# %%
df = df.dropna()
X = df.drop(['Unnamed: 0', 'Stock', 'HPR'], axis=1)
y = df['HPR']

# %%
df.isna().sum(axis=0)
# Out:
# Unnamed: 0         0
# ROA                0
# delta_ROA          0
# CFO                0
# Accrual            0
# delta_leverage     0
# delta_liquidity    0
# issue_new          0
# delta_margin       0
# delta_turn_over    0
# HPR                0
# Stock              0
# dtype: int64

# %%
X.columns
# Out:
# Index(['ROA', 'delta_ROA', 'CFO', 'Accrual', 'delta_leverage',
#        'delta_liquidity', 'issue_new', 'delta_margin', 'delta_turn_over'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train_norm = (X_train - X_train.mean(axis=0)) /  X_train.std(axis=0)
#X_test_norm = (X_test - X_train.mean(axis=0)) /  X_train.std(axis=0)

# %% [markdown]
# # Sklearn Model

# %%
model = ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
                    max_depth=None, max_features='auto', max_leaf_nodes=None,
                    max_samples=None, min_impurity_decrease=0.0,
                    min_impurity_split=None, min_samples_leaf=1,
                    min_samples_split=2, min_weight_fraction_leaf=0.0,
                    n_estimators=100, n_jobs=-1, oob_score=False,
                    random_state=2025, verbose=0, warm_start=False)
model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=2025, verbose=0, warm_start=False)

# %%
y_hat = model.predict(X_test)

# %%
def evaluate(y_test, y_hat):
    #r2 = r2_score(y_test, y_hat)
    mae = mean_absolute_error(y_test, y_hat)
    mse = mean_squared_error(y_test, y_hat)
    #print('R2: ', r2)
    print('MAE: ', mae)
    print('MSE: ', mse)

# %%
evaluate(y_test, y_hat)
# Out:
# MAE:  0.22009383192420184
# MSE:  0.09184166330717501

# %% [markdown]
# ## Cross Validation

# %%
extra = ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
                    max_depth=None, max_features='auto', max_leaf_nodes=None,
                    max_samples=None, min_impurity_decrease=0.0,
                    min_impurity_split=None, min_samples_leaf=1,
                    min_samples_split=2, min_weight_fraction_leaf=0.0,
                    n_estimators=100, n_jobs=-1, oob_score=False,
                    random_state=2025, verbose=0, warm_start=False)

# %%
results = cross_validate(extra, X, y, scoring=('r2', 'neg_mean_absolute_error', 'neg_mean_squared_error'), cv=4)

# %%
results
# Out:
# {'fit_time': array([1.56120062, 0.38427162, 0.37004495, 0.38627386]),
#  'score_time': array([0.10578465, 0.10372519, 0.10390759, 0.10380101]),
#  'test_neg_mean_absolute_error': array([-0.198416  , -0.21024467, -0.22975767, -0.21474333]),
#  'test_neg_mean_squared_error': array([-0.06432838, -0.08195244, -0.09321239, -0.07894024]),
#  'test_r2': array([-0.06734919,  0.02637383,  0.06716149,  0.03139932])}

# %% [markdown]
# # Neural Networks

# %%
model = Sequential()
model.add(Dense(12, activation='tanh', input_dim=X.shape[1], kernel_initializer="he_normal"))
model.add(Dense(4, activation='tanh', kernel_initializer="he_normal"))
model.add(Dense(1, activation='linear'))

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=Huber(), metrics=['mse', 'mae'])

# %%
model.fit(X_train_norm, y_train, epochs=100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2216 - mse: 0.4664 - mae: 0.5453
# Epoch 2/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1314 - mse: 0.2674 - mae: 0.4108
# Epoch 3/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0824 - mse: 0.1661 - mae: 0.3157
# Epoch 4/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0620 - mse: 0.1245 - mae: 0.2704
# Epoch 5/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0535 - mse: 0.1072 - mae: 0.2511
# Epoch 6/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0492 - mse: 0.0985 - mae: 0.2414
# Epoch 7/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0463 - mse: 0.0927 - mae: 0.2349
# Epoch 8/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0441 - mse: 0.0884 - mae: 0.2300
# Epoch 9/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0423 - mse: 0.0848 - mae: 0.2252
# Epoch 10/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0412 - mse: 0.0826 - mae: 0.2224
# Epoch 11/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0402 - mse: 0.0805 - mae: 0.2203
# Epoch 12/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0393 - mse: 0.0787 - mae: 0.2174
# Epoch 13/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0386 - mse: 0.0774 - mae: 0.2158
# Epoch 14/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0382 - mse: 0.0765 - mae: 0.2146
# Epoch 15/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0378 - mse: 0.0757 - mae: 0.2136
# Epoch 16/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0376 - mse: 0.0752 - mae: 0.2130
# Epoch 17/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0372 - mse: 0.0746 - mae: 0.2122
# Epoch 18/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0371 - mse: 0.0742 - mae: 0.2119
# Epoch 19/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0368 - mse: 0.0737 - mae: 0.2111
# Epoch 20/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0366 - mse: 0.0734 - mae: 0.2106
# Epoch 21/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0365 - mse: 0.0730 - mae: 0.2101
# Epoch 22/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0362 - mse: 0.0725 - mae: 0.2093
# Epoch 23/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0360 - mse: 0.0721 - mae: 0.2086
# Epoch 24/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0359 - mse: 0.0719 - mae: 0.2086
# Epoch 25/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0359 - mse: 0.0719 - mae: 0.2083
# Epoch 26/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0356 - mse: 0.0713 - mae: 0.2074
# Epoch 27/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0355 - mse: 0.0711 - mae: 0.2070
# Epoch 28/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0353 - mse: 0.0708 - mae: 0.2066
# Epoch 29/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0352 - mse: 0.0705 - mae: 0.2060
# Epoch 30/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0351 - mse: 0.0703 - mae: 0.2056
# Epoch 31/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0350 - mse: 0.0702 - mae: 0.2054
# Epoch 32/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0350 - mse: 0.0702 - mae: 0.2056
# Epoch 33/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0348 - mse: 0.0697 - mae: 0.2048
# Epoch 34/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0347 - mse: 0.0696 - mae: 0.2049
# Epoch 35/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0346 - mse: 0.0694 - mae: 0.2046
# Epoch 36/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0346 - mse: 0.0693 - mae: 0.2045
# Epoch 37/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0345 - mse: 0.0691 - mae: 0.2042
# Epoch 38/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0344 - mse: 0.0689 - mae: 0.2038
# Epoch 39/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0344 - mse: 0.0690 - mae: 0.2037
# Epoch 40/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0343 - mse: 0.0687 - mae: 0.2035
# Epoch 41/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0343 - mse: 0.0686 - mae: 0.2034
# Epoch 42/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0342 - mse: 0.0685 - mae: 0.2032
# Epoch 43/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0342 - mse: 0.0684 - mae: 0.2029
# Epoch 44/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0339 - mse: 0.0680 - mae: 0.2024
# Epoch 45/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0340 - mse: 0.0682 - mae: 0.2025
# Epoch 46/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0339 - mse: 0.0680 - mae: 0.2024
# Epoch 47/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0339 - mse: 0.0678 - mae: 0.2022
# Epoch 48/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0337 - mse: 0.0676 - mae: 0.2016
# Epoch 49/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0338 - mse: 0.0677 - mae: 0.2020
# Epoch 50/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0338 - mse: 0.0677 - mae: 0.2020
# Epoch 51/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0336 - mse: 0.0674 - mae: 0.2014
# Epoch 52/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0335 - mse: 0.0672 - mae: 0.2011
# Epoch 53/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0336 - mse: 0.0673 - mae: 0.2013
# Epoch 54/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0336 - mse: 0.0672 - mae: 0.2012
# Epoch 55/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0334 - mse: 0.0670 - mae: 0.2006
# Epoch 56/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0333 - mse: 0.0668 - mae: 0.2005
# Epoch 57/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0334 - mse: 0.0669 - mae: 0.2004
# Epoch 58/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0333 - mse: 0.0668 - mae: 0.2006
# Epoch 59/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0332 - mse: 0.0666 - mae: 0.2001
# Epoch 60/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0332 - mse: 0.0666 - mae: 0.1997
# Epoch 61/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0333 - mse: 0.0667 - mae: 0.1999
# Epoch 62/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0333 - mse: 0.0667 - mae: 0.1998
# Epoch 63/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0332 - mse: 0.0664 - mae: 0.1998
# Epoch 64/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0331 - mse: 0.0663 - mae: 0.1996
# Epoch 65/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0331 - mse: 0.0664 - mae: 0.1996
# Epoch 66/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0330 - mse: 0.0660 - mae: 0.1990
# Epoch 67/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0329 - mse: 0.0659 - mae: 0.1990
# Epoch 68/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0330 - mse: 0.0661 - mae: 0.1991
# Epoch 69/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0329 - mse: 0.0659 - mae: 0.1987
# Epoch 70/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0328 - mse: 0.0656 - mae: 0.1985
# Epoch 71/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0328 - mse: 0.0657 - mae: 0.1982
# Epoch 72/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0327 - mse: 0.0656 - mae: 0.1982
# Epoch 73/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0327 - mse: 0.0655 - mae: 0.1979
# Epoch 74/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0327 - mse: 0.0656 - mae: 0.1983
# Epoch 75/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0326 - mse: 0.0654 - mae: 0.1978
# Epoch 76/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0652 - mae: 0.1974
# Epoch 77/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0326 - mse: 0.0653 - mae: 0.1977
# Epoch 78/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0651 - mae: 0.1974
# Epoch 79/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0650 - mae: 0.1973
# Epoch 80/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0325 - mse: 0.0651 - mae: 0.1973
# Epoch 81/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0324 - mse: 0.0649 - mae: 0.1970
# Epoch 82/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0324 - mse: 0.0649 - mae: 0.1968
# Epoch 83/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0324 - mse: 0.0649 - mae: 0.1969
# Epoch 84/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0323 - mse: 0.0649 - mae: 0.1969
# Epoch 85/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0323 - mse: 0.0647 - mae: 0.1966
# Epoch 86/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0322 - mse: 0.0645 - mae: 0.1963
# Epoch 87/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0322 - mse: 0.0645 - mae: 0.1963
# Epoch 88/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0321 - mse: 0.0644 - mae: 0.1959
# Epoch 89/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0321 - mse: 0.0643 - mae: 0.1957
# Epoch 90/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0321 - mse: 0.0643 - mae: 0.1960
# Epoch 91/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0321 - mse: 0.0643 - mae: 0.1962
# Epoch 92/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0320 - mse: 0.0641 - mae: 0.1958
# Epoch 93/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0321 - mse: 0.0643 - mae: 0.1956
# Epoch 94/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0319 - mse: 0.0640 - mae: 0.1954
# Epoch 95/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0318 - mse: 0.0637 - mae: 0.1951
# Epoch 96/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0318 - mse: 0.0637 - mae: 0.1951
# Epoch 97/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0319 - mse: 0.0640 - mae: 0.1955
# Epoch 98/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0318 - mse: 0.0638 - mae: 0.1950
# Epoch 99/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0318 - mse: 0.0636 - mae: 0.1952
# Epoch 100/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0318 - mse: 0.0637 - mae: 0.1949

# %% [markdown]
# ## Evaluation
# ### Train Set

# %%
y_hat_train = model.predict(X_train_norm)

# %%
evaluate(y_train, y_hat_train)
# Out:
# MAE:  0.19367780720212305
# MSE:  0.06303385191190441

# %% [markdown]
# ### Test Set

# %%
y_hat = model.predict(X_test)

# %%
evaluate(y_test, y_hat)
# Out:
# MAE:  0.22707991928403196
# MSE:  0.09728254840674279

# %% [markdown]
# # Export Results

# %%
df_train = df[df.index.isin(X_train.index)]
df_train['HPR_predito'] = y_hat_train
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_test = df[df.index.isin(X_test.index)]
df_test['HPR_predito'] = y_hat
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_final = pd.concat([df_train, df_test])
df_final = df_final.rename(columns={'Unnamed: 0': 'data'})

# %%
df_final.to_csv('/content/drive/My Drive/Grupo Turing/value2_nn_predito.csv', index=False)
